# %% [markdown]
# <a href="https://colab.research.google.com/github/duanfafner/haruandchar/blob/main/Skill%20Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Skill Analysis
# #Client ID: qc8i01ss9wwlr6j9
# #Secret: EXziXjxo
# #Scope: emsi_open

# %%
import requests

url = "https://auth.emsicloud.com/connect/token"

payload = "client_id=qc8i01ss9wwlr6j9&client_secret=EXziXjxo&grant_type=client_credentials&scope=emsi_open"
headers = {"Content-Type": "application/x-www-form-urlencoded"}

response = requests.request("POST", url, data=payload, headers=headers)

print(response.text)
# Out:
# {"access_token":"eyJhbGciOiJSUzI1NiIsImtpZCI6IjNDNjZCRjIzMjBGNkY4RDQ2QzJERDhCMjI0MEVGMTFENTZEQkY3MUYiLCJ0eXAiOiJKV1QiLCJ4NXQiOiJQR2FfSXlEMi1OUnNMZGl5SkE3eEhWYmI5eDgifQ..NLWxUhqsrf4wxRqn5V5g0Q4KvgF5rkBP83uIw8A32FC5tZEUPUXHHFBu-9P9ncQLmnPbfy_n2fN9E5sF6mqFfoEjLKSIh2DFqiJPq2Agc_V6yoryzis4oc4f_GjK5WUbms3YqC7r1RbuGGV3C1tiU8z2yk8wvdftfM1BYOj6ZsYr-C63TBAOJXNwUm0oFK7G7AZVDZdPBT1ZGC661U9sQ1rl1VpTDo8pWwbd_5mUzee9c-UhJa_LOEyF0laBgq0FY_VL_sGDBGQX71_TrUONq5LVXDoV1XvZj3hAFhO9oc-m9nJXCZ5HXEHnef5doY6-wO1IKTAys89rmwbpWV-tZQ","expires_in":3600,"token_type":"Bearer","scope":"emsi_open"}

# %%
import requests

url = "https://emsiservices.com/skills/status"

headers = {"Authorization": "Bearer eyJhbGciOiJSUzI1NiIsImtpZCI6IjNDNjZCRjIzMjBGNkY4RDQ2QzJERDhCMjI0MEVGMTFENTZEQkY3MUYiLCJ0eXAiOiJKV1QiLCJ4NXQiOiJQR2FfSXlEMi1OUnNMZGl5SkE3eEhWYmI5eDgifQ..YJqRodfWIZvFuDxblSHyhi0IXgmoR6DzZ4lCjnMDKua7w0SGXAtNem0MChr4ZAkfFhUSnubpe9PtgLwAfmhokPc7_QbKxxjULFeoiNG3P1SHv2g6IxCKrCwMOEve3QrfG9N7gpmMX3G4y9VJ7zskNKJFyfFor_h-IoUkStC-BP02OY-CGcJwniAHfJHYWNQUZYHpkw-fG5Ry6Z8ao4QFeVIgX4GZDYjua_7VpNdVbdIcpT2CuKAa2kq3PziwK4l-sozeZx_IAJa882dLfSMTtvUC3OEqMKnmLddk4OzpQenYT82ha177lokx9kODxmZqBgZdECY9KedAYn-xpLByjQ"}

response = requests.request("GET", url, headers=headers)

print(response.text)
# Out:
# {"data": {"healthy": true, "message": "Service is healthy"}}

# %%
import requests

url = "https://emsiservices.com/skills/meta"

headers = {"Authorization": "Bearer eyJhbGciOiJSUzI1NiIsImtpZCI6IjNDNjZCRjIzMjBGNkY4RDQ2QzJERDhCMjI0MEVGMTFENTZEQkY3MUYiLCJ0eXAiOiJKV1QiLCJ4NXQiOiJQR2FfSXlEMi1OUnNMZGl5SkE3eEhWYmI5eDgifQ..YJqRodfWIZvFuDxblSHyhi0IXgmoR6DzZ4lCjnMDKua7w0SGXAtNem0MChr4ZAkfFhUSnubpe9PtgLwAfmhokPc7_QbKxxjULFeoiNG3P1SHv2g6IxCKrCwMOEve3QrfG9N7gpmMX3G4y9VJ7zskNKJFyfFor_h-IoUkStC-BP02OY-CGcJwniAHfJHYWNQUZYHpkw-fG5Ry6Z8ao4QFeVIgX4GZDYjua_7VpNdVbdIcpT2CuKAa2kq3PziwK4l-sozeZx_IAJa882dLfSMTtvUC3OEqMKnmLddk4OzpQenYT82ha177lokx9kODxmZqBgZdECY9KedAYn-xpLByjQ"}

response = requests.request("GET", url, headers=headers)

print(response.text)

#latest version 9.29
# Out:
# {"data": {"attribution": {"body": "Lightcast Skills is an open, comprehensive library of skills that uses the same terminology we use in the real world. We select skills that are truly relevant to people, employers, and educators\u2014meaning, they are commonly listed on real-world resumes, professional profiles, and job postings\u2014and we take suggestions from the community.", "title": "Lightcast Skills"}, "latestVersion": "9.29"}}

# %%
# check all versions

url = "https://emsiservices.com/skills/versions"

headers = {"Authorization": "Bearer eyJhbGciOiJSUzI1NiIsImtpZCI6IjNDNjZCRjIzMjBGNkY4RDQ2QzJERDhCMjI0MEVGMTFENTZEQkY3MUYiLCJ0eXAiOiJKV1QiLCJ4NXQiOiJQR2FfSXlEMi1OUnNMZGl5SkE3eEhWYmI5eDgifQ..YJqRodfWIZvFuDxblSHyhi0IXgmoR6DzZ4lCjnMDKua7w0SGXAtNem0MChr4ZAkfFhUSnubpe9PtgLwAfmhokPc7_QbKxxjULFeoiNG3P1SHv2g6IxCKrCwMOEve3QrfG9N7gpmMX3G4y9VJ7zskNKJFyfFor_h-IoUkStC-BP02OY-CGcJwniAHfJHYWNQUZYHpkw-fG5Ry6Z8ao4QFeVIgX4GZDYjua_7VpNdVbdIcpT2CuKAa2kq3PziwK4l-sozeZx_IAJa882dLfSMTtvUC3OEqMKnmLddk4OzpQenYT82ha177lokx9kODxmZqBgZdECY9KedAYn-xpLByjQ"}

response = requests.request("GET", url, headers=headers)

print(response.text)
# Out:
# {"data": ["9.29", "9.28", "9.27", "9.26", "9.25", "9.24", "9.23", "9.22", "9.21", "9.20", "9.19", "9.18", "9.17", "9.16", "9.15", "9.14", "9.13", "9.12", "9.11", "9.10", "9.9", "9.8", "9.7", "9.6", "9.5", "9.4", "9.3", "9.2", "9.1", "9.0", "8.41", "8.40", "8.39", "8.38", "8.37", "8.36", "8.35", "8.34", "8.33", "8.32", "8.31", "8.30", "8.29", "8.28", "8.27", "8.26", "8.25", "8.24", "8.23", "8.22", "8.21", "8.20", "8.19", "8.18", "8.17", "8.16", "8.15", "8.14", "8.13", "8.12", "8.11", "8.10", "8.9", "8.8", "8.7", "8.6", "8.5", "8.4", "8.3", "8.2", "8.1", "8.0", "7.58", "7.57", "7.56", "7.55", "7.54", "7.53", "7.52", "7.51", "7.50", "7.49", "7.48", "7.47", "7.46", "7.45", "7.44", "7.43", "7.42", "7.41", "7.40", "7.39", "7.38", "7.37", "7.36", "7.35", "7.34", "7.33", "7.32", "7.31", "7.30", "7.29", "7.28", "7.27", "7.26", "7.25", "7.24", "7.23", "7.22", "7.21", "7.20", "7.19", "7.18", "7.17", "7.16", "7.15", "7.14", "7.13", "7.12", "7.11", "7.10", "7.9", "7.8", "7.7", "7.6", "7.5", "7.4"
# ...

# %%
url = "https://emsiservices.com/skills/versions/latest"

headers = {"Authorization": "Bearer eyJhbGciOiJSUzI1NiIsImtpZCI6IjNDNjZCRjIzMjBGNkY4RDQ2QzJERDhCMjI0MEVGMTFENTZEQkY3MUYiLCJ0eXAiOiJKV1QiLCJ4NXQiOiJQR2FfSXlEMi1OUnNMZGl5SkE3eEhWYmI5eDgifQ..YJqRodfWIZvFuDxblSHyhi0IXgmoR6DzZ4lCjnMDKua7w0SGXAtNem0MChr4ZAkfFhUSnubpe9PtgLwAfmhokPc7_QbKxxjULFeoiNG3P1SHv2g6IxCKrCwMOEve3QrfG9N7gpmMX3G4y9VJ7zskNKJFyfFor_h-IoUkStC-BP02OY-CGcJwniAHfJHYWNQUZYHpkw-fG5Ry6Z8ao4QFeVIgX4GZDYjua_7VpNdVbdIcpT2CuKAa2kq3PziwK4l-sozeZx_IAJa882dLfSMTtvUC3OEqMKnmLddk4OzpQenYT82ha177lokx9kODxmZqBgZdECY9KedAYn-xpLByjQ"}

response = requests.request("GET", url, headers=headers)

print(response.text)
# Out:
# {"data": {"fields": ["id", "name", "category", "isLanguage", "descriptionSource", "type", "infoUrl", "subcategory", "tags", "isSoftware", "description"], "languageSupport": ["en", "es", "fr"], "removedSkillCount": 6426, "skillCount": 40808, "types": [{"description": "Removed skills are skills that were once part of the skill classification, but have been removed or replaced.", "id": "ST0", "name": "Removed"}, {"description": "Skills that are primarily required within a subset of occupations or equip one to perform a specific task (e.g. \"NumPy\" or \"Hotel Management\"). Also known as technical skills or hard skills.", "id": "ST1", "name": "Specialized Skill"}, {"description": "Skills that are prevalent across many different occupations and industries, including both personal attributes and learned skills. (e.g. \"Communication\" or \"Microsoft Excel\"). Also known as soft skills, human skills, and competencies.", "id": "ST2", "name": "Common Skill"}, {"description": "Certifications 
# ...
